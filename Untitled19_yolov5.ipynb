# %% [markdown]
# <a href="https://colab.research.google.com/github/Gamzeltimur/234309027_GamzeEltimur_SayisalGoruntuisleme_Final/blob/main/Untitled19_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07bbb026-de2d-4d72-acac-c4a82e93966e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07bbb026-de2d-4d72-acac-c4a82e93966e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip ciltkanseri.zip -d dataset
# Out:
# Archive:  ciltkanseri.zip
#   inflating: dataset/README.dataset.txt
#   inflating: dataset/README.roboflow.txt
#   inflating: dataset/data.yaml
#    creating: dataset/train/
#    creating: dataset/train/images/
#  extracting: dataset/train/images/ISIC_0024586_jpg.rf.2941efdd49b454e048e7d26449f197a2.jpg
#  extracting: dataset/train/images/ISIC_0025030_jpg.rf.6630bb0fe541ccf4bd86b3be64b99b78.jpg
#  extracting: dataset/train/images/ISIC_0025209_jpg.rf.f1b363d5ad4e317f40ef962dd31012e1.jpg
#  extracting: dataset/train/images/ISIC_0025450_jpg.rf.95445c9db0fa452d2257b2576e6809a8.jpg
#  extracting: dataset/train/images/ISIC_0025661_jpg.rf.01e20d22fcc0fff5a617a70a48e89d14.jpg
#  extracting: dataset/train/images/ISIC_0025837_jpg.rf.a063a576147b449c617d51c66886f065.jpg
#  extracting: dataset/train/images/ISIC_0026120_jpg.rf.9ad1bed5161a7f4d1264e4afc6c3b1d6.jpg
#  extracting: dataset/train/images/ISIC_0026531_jpg.rf.73922aa192607202536aedcfe95f632c.jpg
# ...

# %%
# !ls dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train

# %%
data_yaml = """
train: dataset/train/images
val: dataset/train/images

nc: 2
names: ['benign', 'malign']
"""

with open("dataset/data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 8 --epochs 50 --data dataset/data.yaml --weights yolov5s.pt --name yolo5-ciltkanseri
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-01-13 07:08:09.944655: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768288089.964856    8396 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 50 --data ../dataset/data.yaml --weights yolov5s.pt --name yolo5-ciltkanseri
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-01-13 07:10:27.774556: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768288227.796403    9026 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768288227.802766    9026 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768288227.819467    9026 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content/yolov5

# %%
# !ls /content/dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train

# %%
import os
print(os.getcwd())
# Out:
# /content/yolov5

# %%
# %cd /content/yolov5
# !python train.py --img 640 --batch 8 --epochs 50 --data ../dataset/data.yaml --weights yolov5s.pt --name yolo5-ciltkanseri
# Out:
# /content/yolov5
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-01-13 07:14:33.652825: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768288473.673060   10097 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768288473.679271   10097 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
data_yaml = """
train: ../dataset/train/images
val: ../dataset/train/images

nc: 2
names: ['benign', 'malign']
"""

with open("dataset/data.yaml", "w") as f:
    f.write(data_yaml)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1042340439.py in <cell line: 0>()
#       7 """
#       8
# ----> 9 with open("dataset/data.yaml", "w") as f:
#      10     f.write(data_yaml)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/data.yaml'

# %%
# %cd /content/dataset
# Out:
# /content/dataset

# %%
data_yaml = """
train: /content/dataset/train/images
val: /content/dataset/train/images

nc: 2
names: ['benign', 'malign']
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 8 --epochs 50 --data /content/dataset/data.yaml --weights yolov5s.pt --name yolo5-ciltkanseri
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-01-13 07:24:13.529992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768289053.550213   12573 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768289053.556206   12573 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768289053.571311   12573 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
